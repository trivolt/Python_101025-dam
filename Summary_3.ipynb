# %% [markdown]
# # Summary 3

# %%
import b2f

print(b2f.float_to_binary_string(0.1))
# Out:
# 0.0001100110011001100110011001100110011001100110011001

# %%
print(b2f.binary_string_to_float("0.000110011001100110011001"))
# Out:
# 0.09999996423721313

# %% [markdown]
# ### Полезные материалы
# https://skillbox.ru/media/code/chisla-s-plavayushchey-tochkoy-chto-eto-takoe-i-kak-oni-rabotayut/

# %%
print(round(2.555,2))
print(round(3.555,2))
print(round(4.555,2))
print(round(5.555,2))
# Out:
# 2.56
# 3.56
# 4.55
# 5.55

# %%
from decimal import Decimal

num1 = 2.555
num2 = 3.555
num3 = 4.555
num4 = 5.555
print(num1, ": ", Decimal(num1))
print(num2, ": ", Decimal(num2))
print(num3, ": ", Decimal(num3))
print(num4, ": ", Decimal(num4))
# Out:
# 2.555 :  2.555000000000000159872115546022541821002960205078125
# 3.555 :  3.555000000000000159872115546022541821002960205078125
# 4.555 :  4.55499999999999971578290569595992565155029296875
# 5.555 :  5.55499999999999971578290569595992565155029296875

# %%
num = float(input("Введите вещественное число: "))

if num > 0:
    rounded_num = int(num + 0.5)
else:
    rounded_num = int(num - 0.5)

print("Округленное значение:", rounded_num)
# Out:
# Введите вещественное число:  1.4
# Округленное значение: 1
